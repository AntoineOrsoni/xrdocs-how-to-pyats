# %% [markdown]
# ## Commit rollback
#
# ```
# configuration to-exclude no-description
# ```
#
# Get back to the configuration status at commit "no description"
#
# ## From SCP
#
# ```
# scp cisco@172.40.0.1:/home/cisco/text.txt harddisk:/text.txt
# scp cisco@172.40.0.1:/home/cisco/xrd-tools/samples/xr_compose_topos/segment-routing/xrd-1-startup.cfg harddisk:/xrd-1-startup.cfg
# load harddisk:xrd-1-startup.cfg
# commit replace
# ```
#
# (replace is important, otherwise it doesn't replace)
# double check that the file exists, otherwise the configuration will be reseted to 0
#
# ## Enabling NETCONF on IOS XR
#
# netconf-yang agent
#  ssh
# !
# netconf agent tty
# !
# ssh server v2
# ssh server vrf default
# ssh server netconf vrf default
# end
#
# ## RPC Request to get the running-config from an IOS XR device
#
# ```
# rpc_request = '''
# <rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <get-config>
#        <source>
#          <running/>
#        </source>
#    </get-config>
# </rpc>
#
# '''
# ```
#
# ## Connecting via multiple methods at once to a device
#
# https://pubhub.devnetcloud.com/media/genie-docs/docs/cookbooks/harness.html#what-can-you-do-with-the-mapping-datafile
# https://pubhub.devnetcloud.com/media/genie-docs/docs/userguide/harness/user/gettingstarted.html#getting-genie
# https://pubhub.devnetcloud.com/media/genie-docs/docs/userguide/harness/user/datafile.html#pts-datafile

# %%
from genie import testbed
from unicon.eal.dialogs import Statement, Dialog
import xmltodict

testbed = testbed.load('./testbed.yaml')
source = testbed.devices['xrd-source']

source.connect(via='netconf', log_stdout=True)
source.connected
# Out:
# 2023-06-22T17:05:11: %UNICON-WARNING: Lost connection to the proxy host js, reconnecting..
# 2023-06-22T17:05:22: %UNICON-INFO: Connecting proxy host js
#
# 2023-06-22 17:05:22,802: %UNICON-INFO: +++ js logfile /tmp/js-20230622T170522801.log +++
#
# 2023-06-22 17:05:22,802: %UNICON-INFO: +++ Unicon plugin linux (unicon.plugins.linux) +++
#
# 2023-06-22 17:05:22,809: %UNICON-INFO: +++ connection to spawn: ssh -l cisco 10.48.35.164, id: 4988801792 +++
#
# 2023-06-22 17:05:22,811: %UNICON-INFO: connection to js
# cisco@10.48.35.164's password:
# Welcome to Ubuntu 18.04.3 LTS (GNU/Linux 4.15.0-208-generic x86_64)
#
#  * Documentation:  https://help.ubuntu.com
#  * Management:     https://landscape.canonical.com
#  * Support:        https://ubuntu.com/advantage
#
#   System information as of Thu Jun 22 15:04:32 UTC 2023
#
#   System load:                    11.95
#   Usage of /:                     7.8% of 195.80GB
#   Memory usage:                   56%
# ...

# %%
## RPC Request to get the running-config from an IOS XR device

rpc_request = '''
<rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
  <get-config>
       <source>
         <running/>
       </source>
   </get-config>
</rpc>  

'''

reply_xml = source.netconf.request(rpc_request, timeout=120)
reply = xmltodict.parse(reply_xml)
# Out:
# 2023-06-22T11:57:09: %NETCONF-INFO: Sending rpc...
# 2023-06-22T11:57:09: %NETCONF-INFO: <rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <get-config>
#     <source>
#       <running/>
#     </source>
#   </get-config>
# </rpc>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 14
#       1 ## RPC Request to get the running-config from an IOS XR device
#       3 rpc_request = '''
#       4 <rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#       5   <get-config>
#    (...)
#      11
#      12 '''
# ---> 14 reply_xml = source.netconf.request(rpc_request, timeout=120)
#      15 reply = xmltodict.parse(reply_xml)
#
# File ~/Documents/Programmability/XRDocs/how-to-pyATS/.venv/lib/python3.10/site-packages/yang/connector/netconf.py:778, in Netconf.request(self, msg, timeout, return_obj)
# ...

# %%
print(reply_xml)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="101" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <data>
#   <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg">
#    <agent>
#     <ssh>
#      <enable></enable>
#     </ssh>
#    </agent>
#   </netconf-yang>
#   <host-names xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg">
#    <host-name>xrd-source</host-name>
#   </host-names>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg">
#    <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg">
#     <username>
#      <ordering-index>0</ordering-index>
#      <name>cisco</name>
#      <usergroup-under-usernames>
#       <usergroup-under-username>
#        <name>root-lr</name>
#       </usergroup-under-username>
#       <usergroup-under-username>
#        <name>cisco-support</name>
#       </usergroup-under-username>
#      </usergroup-under-usernames>
#      <secret>
#       <type>type10</type>
# ...

# %%
all_config_xml = '''
<?xml version="1.0"?>
<rpc-reply message-id="101" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
<edit-config>
<target><candidate/></target>
<config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
  <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg">
   <agent>
    <ssh>
     <enable></enable>
    </ssh>
   </agent>
  </netconf-yang>
  <host-names xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg">
   <host-name>xrd-source</host-name>
  </host-names>
  <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg">
   <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg">
    <username>
     <ordering-index>0</ordering-index>
     <name>cisco</name>
     <usergroup-under-usernames>
      <usergroup-under-username>
       <name>root-lr</name>
      </usergroup-under-username>
      <usergroup-under-username>
       <name>cisco-support</name>
      </usergroup-under-username>
     </usergroup-under-usernames>
     <secret>
      <type>type10</type>
      <secret10>$6$qAJ4HZ/N........$XEn4vHqA9x02R2Rur5ocSHz5FZJXuz5cjNc/KOya5ywcaxRn8Ytgzzd/EZTzKhfq9yt.kBwQJpf1I31HPNV611</secret10>
     </secret>
    </username>
   </usernames>
  </aaa>
  <tty xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-tty-server-cfg">
   <tty-lines>
    <tty-line>
     <name>console</name>
     <exec>
      <timeout>
       <minutes>0</minutes>
       <seconds>0</seconds>
      </timeout>
     </exec>
     <general>
      <absolute-timeout>0</absolute-timeout>
     </general>
     <connection xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-tty-management-cfg">
      <session-timeout>
       <timeout>0</timeout>
       <direction>in</direction>
      </session-timeout>
     </connection>
    </tty-line>
    <tty-line>
     <name>default</name>
     <exec>
      <timeout>
       <minutes>0</minutes>
       <seconds>0</seconds>
      </timeout>
     </exec>
     <general>
      <absolute-timeout>0</absolute-timeout>
     </general>
     <connection xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-tty-management-cfg">
      <session-timeout>
       <timeout>0</timeout>
       <direction>in</direction>
      </session-timeout>
      <transport-input>
       <select>some</select>
       <protocol1>ssh</protocol1>
      </transport-input>
     </connection>
    </tty-line>
   </tty-lines>
  </tty>
  <netconf xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-xml-ttyagent-cfg">
   <agent>
    <tty>
     <enable></enable>
    </tty>
   </agent>
  </netconf>
  <ssh xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg">
   <server>
    <v2></v2>
    <vrf-table>
     <vrf>
      <vrf-name>default</vrf-name>
      <enable></enable>
     </vrf>
    </vrf-table>
    <netconf>830</netconf>
    <netconf-vrf-table>
     <vrf>
      <vrf-name>default</vrf-name>
      <enable></enable>
     </vrf>
    </netconf-vrf-table>
   </server>
  </ssh>
  <interface-configurations xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg">
   <interface-configuration>
    <active>act</active>
    <interface-name>MgmtEth0/RP0/CPU0/0</interface-name>
    <ipv4-network xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg">
     <addresses>
      <primary>
       <address>172.40.0.200</address>
       <netmask>255.255.255.0</netmask>
      </primary>
     </addresses>
    </ipv4-network>
   </interface-configuration>
   <interface-configuration>
    <active>act</active>
    <interface-name>GigabitEthernet0/0/0/0</interface-name>
    <ipv4-network xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg">
     <addresses>
      <primary>
       <address>10.1.1.2</address>
       <netmask>255.255.255.0</netmask>
      </primary>
     </addresses>
    </ipv4-network>
   </interface-configuration>
  </interface-configurations>
  <routing-policy xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-policy-repository-cfg">
   <sets>
    <extended-community-opaque-sets>
     <extended-community-opaque-set>
      <set-name>100</set-name>
      <rpl-extended-community-opaque-set>extcommunity-set opaque 100
  100
end-set
</rpl-extended-community-opaque-set>
     </extended-community-opaque-set>
    </extended-community-opaque-sets>
   </sets>
   <route-policies>
    <route-policy>
     <route-policy-name>100</route-policy-name>
     <rpl-route-policy>route-policy 100
  set extcommunity color 100
  pass
end-policy
</rpl-route-policy>
    </route-policy>
   </route-policies>
  </routing-policy>
  <syslog xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-infra-syslog-cfg">
   <console-logging>
    <logging-level>disable</logging-level>
   </console-logging>
   <monitor-logging>
    <logging-level>debug</logging-level>
   </monitor-logging>
  </syslog>
  <router-static xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-cfg">
   <default-vrf>
    <address-family>
     <vrfipv4>
      <vrf-unicast>
       <vrf-prefixes>
        <vrf-prefix>
         <prefix>0.0.0.0</prefix>
         <prefix-length>0</prefix-length>
         <vrf-route>
          <vrf-next-hop-table>
           <vrf-next-hop-next-hop-address>
            <next-hop-address>10.1.1.3</next-hop-address>
           </vrf-next-hop-next-hop-address>
          </vrf-next-hop-table>
         </vrf-route>
        </vrf-prefix>
       </vrf-prefixes>
      </vrf-unicast>
     </vrfipv4>
    </address-family>
   </default-vrf>
  </router-static>
  <call-home xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-call-home-cfg">
   <active></active>
   <contact-smart-licensing>true</contact-smart-licensing>
   <profiles>
    <profile>
     <profile-name>CiscoTAC-1</profile-name>
     <active></active>
     <methods>
      <method>
       <method>email</method>
       <enable>false</enable>
      </method>
      <method>
       <method>http</method>
       <enable>true</enable>
      </method>
     </methods>
    </profile>
   </profiles>
  </call-home>
  <vrfs xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-infra-rsi-cfg">
   <vrf>
    <vrf-name>100</vrf-name>
    <create></create>
    <afs>
     <af>
      <af-name>ipv4</af-name>
      <saf-name>unicast</saf-name>
      <topology-name>default</topology-name>
      <create></create>
      <bgp xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-cfg">
       <import-route-targets>
        <route-targets>
         <route-target>
          <type>as</type>
          <as-or-four-byte-as>
           <as-xx>0</as-xx>
           <as>100</as>
           <as-index>100</as-index>
           <stitching-rt>0</stitching-rt>
          </as-or-four-byte-as>
         </route-target>
        </route-targets>
       </import-route-targets>
       <export-route-policy>100</export-route-policy>
       <export-route-targets>
        <route-targets>
         <route-target>
          <type>as</type>
          <as-or-four-byte-as>
           <as-xx>0</as-xx>
           <as>100</as>
           <as-index>100</as-index>
           <stitching-rt>0</stitching-rt>
          </as-or-four-byte-as>
         </route-target>
        </route-targets>
       </export-route-targets>
      </bgp>
     </af>
    </afs>
   </vrf>
  </vrfs>
  <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-netconf-yang-cfg">
   <agent>
    <ssh/>
   </agent>
  </netconf-yang>
  <hostname xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-hostname-cfg">
   <system-network-name>xrd-source</system-network-name>
  </hostname>
  <logging xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-logging-cfg">
   <console>disable</console>
   <monitor>debugging</monitor>
  </logging>
  <vrfs xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-vrf-cfg">
   <vrf>
    <vrf-name>100</vrf-name>
    <address-family>
     <ipv4>
      <unicast>
       <import xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-bgp-cfg">
        <route-target>
         <two-byte-as-rts>
          <two-byte-as-rt>
           <as-number>100</as-number>
           <index>100</index>
           <stitching>false</stitching>
          </two-byte-as-rt>
         </two-byte-as-rts>
        </route-target>
       </import>
       <export xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-bgp-cfg">
        <route-policy>100</route-policy>
        <route-target>
         <two-byte-as-rts>
          <two-byte-as-rt>
           <as-number>100</as-number>
           <index>100</index>
           <stitching>false</stitching>
          </two-byte-as-rt>
         </two-byte-as-rts>
        </route-target>
       </export>
      </unicast>
     </ipv4>
    </address-family>
   </vrf>
  </vrfs>
  <router xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-static-cfg">
   <static>
    <address-family>
     <ipv4>
      <unicast>
       <prefixes>
        <prefix>
         <prefix-address>0.0.0.0</prefix-address>
         <prefix-length>0</prefix-length>
         <nexthop-addresses>
          <nexthop-address>
           <address>10.1.1.3</address>
          </nexthop-address>
         </nexthop-addresses>
        </prefix>
       </prefixes>
      </unicast>
     </ipv4>
    </address-family>
   </static>
  </router>
  <call-home xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-call-home-cfg">
   <service>
    <active/>
   </service>
   <contact>
    <smart-licensing/>
   </contact>
   <profiles>
    <profile>
     <profile-name>CiscoTAC-1</profile-name>
     <active/>
     <destination>
      <transport-method>
       <email>
        <disable/>
       </email>
       <http/>
      </transport-method>
     </destination>
    </profile>
   </profiles>
  </call-home>
  <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-aaa-cfg">
   <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-aaa-task-user-cfg">
    <username>
     <ordering-index>0</ordering-index>
     <name>cisco</name>
     <group>
      <root-lr/>
      <cisco-support/>
     </group>
     <secret>
      <ten>$6$qAJ4HZ/N........$XEn4vHqA9x02R2Rur5ocSHz5FZJXuz5cjNc/KOya5ywcaxRn8Ytgzzd/EZTzKhfq9yt.kBwQJpf1I31HPNV611</ten>
     </secret>
    </username>
   </usernames>
  </aaa>
  <line xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-line-cfg">
   <console>
    <exec-timeout xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-line-exec-timeout-cfg">
     <timeout-in-minutes>0</timeout-in-minutes>
     <timeout-in-seconds>0</timeout-in-seconds>
    </exec-timeout>
    <absolute-timeout xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-line-general-cfg">0</absolute-timeout>
    <session-timeout>
     <timeout-interval>0</timeout-interval>
    </session-timeout>
   </console>
   <default>
    <exec-timeout xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-line-exec-timeout-cfg">
     <timeout-in-minutes>0</timeout-in-minutes>
     <timeout-in-seconds>0</timeout-in-seconds>
    </exec-timeout>
    <absolute-timeout xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-line-general-cfg">0</absolute-timeout>
    <session-timeout>
     <timeout-interval>0</timeout-interval>
    </session-timeout>
    <transport>
     <input>
      <ssh/>
     </input>
    </transport>
   </default>
  </line>
  <ssh xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-ssh-cfg">
   <server>
    <v2/>
    <vrfs>
     <vrf>
      <vrf-name>default</vrf-name>
     </vrf>
    </vrfs>
    <netconf>
     <port>830</port>
     <vrfs>
      <vrf>
       <vrf-name>default</vrf-name>
      </vrf>
     </vrfs>
    </netconf>
   </server>
  </ssh>
  <interfaces xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-interface-cfg">
   <interface>
    <interface-name>MgmtEth0/RP0/CPU0/0</interface-name>
    <ipv4>
     <addresses xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-ip-address-cfg">
      <address>
       <address>172.40.0.200</address>
       <netmask>255.255.255.0</netmask>
      </address>
     </addresses>
    </ipv4>
   </interface>
   <interface>
    <interface-name>GigabitEthernet0/0/0/0</interface-name>
    <ipv4>
     <addresses xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-ip-address-cfg">
      <address>
       <address>10.1.1.2</address>
       <netmask>255.255.255.0</netmask>
      </address>
     </addresses>
    </ipv4>
   </interface>
  </interfaces>
  <netconf xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-um-xml-agent-cfg">
   <agent>
    <tty/>
   </agent>
  </netconf>
  <system xmlns="http://openconfig.net/yang/system">
   <config>
    <hostname>xrd-source</hostname>
   </config>
   <aaa>
    <authentication>
     <users>
      <user>
       <username>cisco</username>
       <config>
        <username>cisco</username>
        <role>root-lr</role>
        <password-hashed>$6$qAJ4HZ/N........$XEn4vHqA9x02R2Rur5ocSHz5FZJXuz5cjNc/KOya5ywcaxRn8Ytgzzd/EZTzKhfq9yt.kBwQJpf1I31HPNV611</password-hashed>
       </config>
      </user>
     </users>
    </authentication>
   </aaa>
   <ssh-server>
    <config>
     <enable>true</enable>
     <protocol-version>V2</protocol-version>
    </config>
   </ssh-server>
  </system>
  <interfaces xmlns="http://openconfig.net/yang/interfaces">
   <interface>
    <name>MgmtEth0/RP0/CPU0/0</name>
    <config>
     <name>MgmtEth0/RP0/CPU0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
    </config>
    <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
     <config>
      <auto-negotiate>false</auto-negotiate>
     </config>
    </ethernet>
    <subinterfaces>
     <subinterface>
      <index>0</index>
      <ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
       <addresses>
        <address>
         <ip>172.40.0.200</ip>
         <config>
          <ip>172.40.0.200</ip>
          <prefix-length>24</prefix-length>
         </config>
        </address>
       </addresses>
      </ipv4>
     </subinterface>
    </subinterfaces>
   </interface>
   <interface>
    <name>GigabitEthernet0/0/0/0</name>
    <config>
     <name>GigabitEthernet0/0/0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
    </config>
    <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
     <config>
      <auto-negotiate>false</auto-negotiate>
     </config>
    </ethernet>
    <subinterfaces>
     <subinterface>
      <index>0</index>
      <ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
       <addresses>
        <address>
         <ip>10.1.1.2</ip>
         <config>
          <ip>10.1.1.2</ip>
          <prefix-length>24</prefix-length>
         </config>
        </address>
       </addresses>
      </ipv4>
     </subinterface>
    </subinterfaces>
   </interface>
  </interfaces>
  <routing-policy xmlns="http://openconfig.net/yang/routing-policy">
   <policy-definitions>
    <policy-definition>
     <config>
      <name>100</name>
     </config>
     <name>100</name>
    </policy-definition>
   </policy-definitions>
  </routing-policy>
  <network-instances xmlns="http://openconfig.net/yang/network-instance">
   <network-instance>
    <name>default</name>
    <protocols>
     <protocol>
      <identifier xmlns:idx="http://openconfig.net/yang/policy-types">idx:STATIC</identifier>
      <name>DEFAULT</name>
      <config>
       <identifier xmlns:idx="http://openconfig.net/yang/policy-types">idx:STATIC</identifier>
       <name>DEFAULT</name>
      </config>
      <static-routes>
       <static>
        <prefix>0.0.0.0/0</prefix>
        <config>
         <prefix>0.0.0.0/0</prefix>
        </config>
        <next-hops>
         <next-hop>
          <index>##10.1.1.3##</index>
          <config>
           <index>##10.1.1.3##</index>
           <next-hop>10.1.1.3</next-hop>
          </config>
         </next-hop>
        </next-hops>
       </static>
      </static-routes>
     </protocol>
    </protocols>
    <config>
     <name>default</name>
    </config>
   </network-instance>
   <network-instance>
    <name>100</name>
    <config>
     <name>100</name>
     <enabled>true</enabled>
     <enabled-address-families xmlns:idx="http://openconfig.net/yang/openconfig-types">idx:IPV4</enabled-address-families>
    </config>
   </network-instance>
  </network-instances>
 </config>
</edit-config>
</rpc-reply>

'''

# %%
rpc_request = '''
<rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
    <traceroute xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-traceroute-act">
        <destination>
        <destination>10.3.1.3</destination>
        </destination>
    </traceroute>
</rpc>
'''

reply = xmltodict.parse(source.netconf.request(rpc_request, timeout=120))
# Out:
# 2023-06-22T17:05:33: %NETCONF-INFO: Sending rpc...
# 2023-06-22T17:05:33: %NETCONF-INFO: <rpc xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <traceroute xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-traceroute-act">
#     <destination>
#       <destination>10.3.1.3</destination>
#     </destination>
#   </traceroute>
# </rpc>
# 2023-06-22T17:05:37: %NETCONF-INFO: Receiving rpc-reply after 3.967 sec...
# 2023-06-22T17:05:37: %NETCONF-INFO: <rpc-reply xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <traceroute-response xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-traceroute-act">
#     <ipv4>
#       <destination>10.3.1.3</destination>
#       <hops>
#         <hop>
#           <hop-index>1</hop-index>
#           <hop-address>10.1.1.3</hop-address>
#           <probes>
#             <probe>
#               <probe-index>0</probe-index>
#               <delta-time>4</delta-time>
#             </probe>
#             <probe>
# ...

# %%
print(reply)
# Out:
# {'rpc-reply': {'@message-id': '101', '@xmlns': 'urn:ietf:params:xml:ns:netconf:base:1.0', 'traceroute-response': {'@xmlns': 'http://cisco.com/ns/yang/Cisco-IOS-XR-traceroute-act', 'ipv4': {'destination': '10.3.1.3', 'hops': {'hop': [{'hop-index': '1', 'hop-address': '10.1.1.3', 'probes': {'probe': [{'probe-index': '0', 'delta-time': '14'}, {'probe-index': '1', 'delta-time': '3'}, {'probe-index': '2', 'delta-time': '3'}]}}, {'hop-index': '2', 'hop-address': '100.101.103.103', 'probes': {'probe': [{'probe-index': '0', 'delta-time': '32'}, {'probe-index': '1', 'delta-time': '13'}, {'probe-index': '2', 'delta-time': '9'}]}}, {'hop-index': '3', 'hop-address': '100.103.104.104', 'probes': {'probe': [{'probe-index': '0', 'delta-time': '86'}, {'probe-index': '1', 'delta-time': '11'}, {'probe-index': '2', 'delta-time': '62'}]}}, {'hop-index': '4', 'hop-address': '100.102.104.102', 'probes': {'probe': [{'probe-index': '0', 'delta-time': '67'}, {'probe-index': '1', 'delta-time': '12'}, {'probe-
# ...

# %%
hops = []

for hop in reply['rpc-reply']['traceroute-response']['ipv4']['hops']['hop']:
    hops.append(hop['hop-address'])

# %%
hops
# Out:
# ['10.1.1.3',
#  '100.101.103.103',
#  '100.103.104.104',
#  '100.102.104.102',
#  '10.3.1.3']
